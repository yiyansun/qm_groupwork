# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import statsmodels.formula.api as smf
import statsmodels

# %%
df = pd.read_csv('https://raw.githubusercontent.com/yiyansun/qm_groupwork/main/data/datasource.csv?token=GHSAT0AAAAAACKY7VGE2GJ3A7ZBS3BDEVHAZLJC4LA')

# %%
df
# Out:
#               borough_name borough_code  borough_area_hectare  \
# 0           City of London    E09000001                314.94
# 1     Barking and Dagenham    E09000002               3779.93
# 2                   Barnet    E09000003               8674.84
# 3                   Bexley    E09000004               6428.65
# 4                    Brent    E09000005               4323.27
# 5                  Bromley    E09000006              15013.49
# 6                   Camden    E09000007               2178.93
# 7                  Croydon    E09000008               8649.44
# 8                   Ealing    E09000009               5554.43
# 9                  Enfield    E09000010               8220.02
# 10               Greenwich    E09000011               5044.19
# 11                 Hackney    E09000012               1904.90
# 12  Hammersmith and Fulham    E09000013               1715.41
# 13                Haringey    E09000014               2959.84
# 14                  Harrow    E09000015               5046.33
# 15                Havering    E09000016              11445.74
# 16              Hillingdon    E09000017              11570.06
# 17                Hounslow    E09000018               5658.54
# 18               Islington    E09000019               1485.67
# 19  Kensington and Chelsea    E09000020               1238.38
# 20    Kingston upon Thames    E09000021               3726.12
# 21                 Lambeth    E09000022               2724.94
# 22                Lewisham    E09000023               3531.71
# 23                  Merton    E09000024               3762.47
# 24                  Newham    E09000025               3857.81
# 25               Redbridge    E09000026               5644.22
# 26    Richmond upon Thames    E09000027               5876.11
# 27               Southwark    E09000028               2991.34
# 28                  Sutton    E09000029               4384.70
# 29           Tower Hamlets    E09000030               2157.50
# 30          Waltham Forest    E09000031               3880.79
# 31              Wandsworth    E09000032               3522.02
# 32     City of Westminster    E09000033               2203.00
#
#     green_area_hectare  blue _area_hectare  green+blue_area_hectare  \
# 0                17.61               24.31                    41.92
# 1              1481.78              230.50                  1712.28
# 2              5030.91               60.01                  5090.92
# 3              2759.07              437.52                  3196.59
# 4              1726.56               44.59                  1771.15
# 5             10262.64               56.96                 10319.60
# 6               943.02               19.81                   962.83
# 7              4802.84               11.56                  4814.40
# 8              2441.65               52.21                  2493.87
# 9              4352.73              424.01                  4776.74
# 10             2180.09              341.94                  2522.03
# 11              738.97               42.56                   781.53
# 12              473.37               79.40                   552.77
# 13             1288.89               23.41                  1312.29
# 14             2796.61               23.88                  2820.50
# 15             7551.97              401.81                  7953.78
# 16             6316.80              377.17                  6693.97
# 17             2677.23              178.21                  2855.44
# 18              518.14                3.95                   522.09
# 19              376.07               28.56                   404.64
# 20             1953.41               39.28                  1992.69
# 21              896.81               44.28                   941.09
# 22             1421.51               28.39                  1449.90
# 23             1835.36               31.92                  1867.29
# 24             1182.08              365.05                  1547.13
# 25             3023.23               79.78                  3103.01
# 26             3642.68              307.94                  3950.61
# 27             1126.72              126.48                  1253.19
# 28             2178.83               54.78                  2233.61
# 29              547.61              253.56                   801.16
# 30             1721.34              242.10                  1963.44
# 31             1373.92              112.57                  1486.49
# 32              687.28               97.18                   784.46
#
#     percent_green  percent_blue  percent_green+blue population  ...  \
# 0            5.59          7.72               13.31      7,400  ...
# 1           39.20          6.10               45.30    185,900  ...
# 2           57.99          0.69               58.69    356,400  ...
# 3           42.92          6.81               49.72    232,000  ...
# 4           39.94          1.03               40.97    311,200  ...
# 5           68.36          0.38               68.74    309,400  ...
# 6           43.28          0.91               44.19    220,300  ...
# 7           55.53          0.13               55.66    363,400  ...
# 8           43.96          0.94               44.90    338,400  ...
# 9           52.95          5.16               58.11    312,500  ...
# 10          43.22          6.78               50.00    254,600  ...
# 11          38.79          2.23               41.03    246,300  ...
# 12          27.60          4.63               32.22    182,500  ...
# 13          43.55          0.79               44.34    254,900  ...
# 14          55.42          0.47               55.89    239,100  ...
# 15          65.98          3.51               69.49    237,200  ...
# 16          54.60          3.26               57.86    273,900  ...
# 17          47.31          3.15               50.46    254,000  ...
# 18          34.88          0.27               35.14    206,100  ...
# 19          30.37          2.31               32.67    158,700  ...
# 20          52.42          1.05               53.48    160,100  ...
# 21          32.91          1.62               34.54    303,100  ...
# 22          40.25          0.80               41.05    275,900  ...
# 23          48.78          0.85               49.63    199,700  ...
# 24          30.64          9.46               40.10    308,000  ...
# 25          53.56          1.41               54.98    279,000  ...
# 26          61.99          5.24               67.23    187,000  ...
# 27          37.67          4.23               41.89    288,300  ...
# 28          49.69          1.25               50.94    190,100  ...
# 29          25.38         11.75               37.13    254,100  ...
# 30          44.36          6.24               50.59    258,200  ...
# 31          39.01          3.20               42.21    307,000  ...
# 32          31.20          4.41               35.61    219,400  ...
#
#    number_annual_age15+_females meanpercent_homes_with_good_access  \
# 0                             0                                  0
# 1                             2                                 72
# 2                            13                                 82
# 3                             4                                 83
# 4                             3                                 82
# 5                             8                                 82
# 6                             8                                 71
# 7                             6                                 70
# 8                             1                                 75
# 9                             2                                 54
# 10                            4                                 87
# 11                            2                                 74
# 12                            0                                 64
# 13                            8                                 82
# 14                            4                                 61
# 15                            2                                 59
# 16                            3                                 84
# 17                            1                                 77
# 18                            6                                 68
# 19                            5                                 90
# 20                            0                                 68
# 21                            7                                 63
# 22                            4                                 86
# 23                            1                                 86
# 24                           11                                 61
# 25                            2                                 82
# 26                            3                                 89
# 27                            6                                 70
# 28                            3                                 70
# 29                            3                                 65
# 30                            1                                 58
# 31                            3                                 91
# 32                            2                                 73
#
#    meanpercent_home_with_deficiency_access  any_neurotic_disorder_per1000  \
# 0                                      100                          190.6
# 1                                       28                          177.5
# 2                                       18                          167.4
# 3                                       17                          155.6
# 4                                       18                          182.3
# 5                                       18                          157.7
# 6                                       29                          206.3
# 7                                       30                          172.4
# 8                                       25                          174.4
# 9                                       46                          170.7
# 10                                      13                          189.8
# 11                                      26                          212.7
# 12                                      36                          205.7
# 13                                      18                          200.9
# 14                                      39                          153.9
# 15                                      41                          151.4
# 16                                      16                          160.1
# 17                                      23                          168.9
# 18                                      32                          212.7
# 19                                      10                          195.2
# 20                                      32                          164.3
# 21                                      37                          209.9
# 22                                      14                          197.9
# 23                                      14                          171.4
# 24                                      39                          190.9
# 25                                      18                          161.6
# 26                                      11                          166.4
# 27                                      30                          206.4
# 28                                      30                          161.2
# 29                                      35                          198.0
# 30                                      42                          183.8
# 31                                       9                          200.1
# 32                                      27                          195.7
#
#     all_phobias_per1000  depressive_episode_per1000  \
# 0             22.041537                   39.516764
# 1             21.301491                   34.411868
# 2             19.969920                   32.483563
# 3             18.456990                   30.428115
# 4             21.760559                   35.195831
# 5             18.742408                   30.980945
# 6             24.698391                   39.258031
# 7             20.718164                   33.733624
# 8             20.809948                   34.029337
# 9             20.369817                   33.357213
# 10            22.792313                   36.736902
# 11            25.920357                   40.635105
# 12            24.749521                   39.240017
# 13            24.234965                   38.844843
# 14            18.229367                   30.016719
# 15            17.744171                   29.675237
# 16            19.074677                   31.186775
# 17            20.144889                   32.967591
# 18            25.658976                   40.550139
# 19            23.401524                   37.908490
# 20            19.535155                   32.130045
# 21            25.343774                   40.629619
# 22            24.041154                   38.589372
# 23            20.565539                   33.278106
# 24            22.965395                   36.685244
# 25            19.202900                   31.596520
# 26            20.024005                   33.150582
# 27            24.883227                   39.930561
# 28            19.237880                   31.677857
# 29            23.585961                   37.496673
# 30            22.253917                   35.569845
# 31            24.251306                   37.571370
# 32            23.254080                   37.335829
#
#     generalised_anxiety_disorder_per1000  mixed_anxiety_depression  \
# 0                                   60.4                      84.4
# 1                                   51.1                      82.6
# 2                                   49.0                      77.4
# 3                                   45.9                      71.7
# 4                                   53.0                      84.4
# 5                                   47.2                      72.4
# 6                                   58.5                      97.0
# 7                                   50.9                      79.5
# 8                                   51.7                      80.0
# 9                                   50.4                      78.7
# 10                                  54.9                      88.3
# 11                                  61.1                      99.6
# 12                                  59.6                      95.9
# 13                                  58.7                      93.0
# 14                                  45.4                      70.8
# 15                                  44.8                      69.5
# 16                                  46.5                      74.1
# 17                                  49.8                      77.6
# 18                                  60.6                     100.0
# 19                                  57.2                      90.4
# 20                                  48.1                      75.6
# 21                                  62.3                      96.8
# 22                                  58.5                      91.4
# 23                                  50.8                      78.9
# 24                                  54.2                      88.8
# 25                                  47.7                      74.3
# 26                                  50.7                      75.7
# 27                                  60.2                      95.6
# 28                                  48.2                      73.9
# 29                                  56.3                      92.9
# 30                                  53.8                      84.7
# 31                                  57.1                      94.4
# 32                                  55.6                      91.6
#
#     obsessive_compulsive_disorder_per1000  panic_ disorder_per1000
# 0                                    15.9                      9.4
# 1                                    15.2                      8.2
# 2                                    14.1                      7.9
# 3                                    13.0                      7.3
# 4                                    15.5                      8.5
# 5                                    13.1                      7.4
# 6                                    17.8                      9.5
# 7                                    14.6                      8.0
# 8                                    14.7                      8.2
# 9                                    14.4                      7.9
# 10                                   16.2                      8.8
# 11                                   18.2                      9.7
# 12                                   17.4                      9.6
# 13                                   17.1                      9.3
# 14                                   12.9                      7.3
# 15                                   12.7                      7.2
# 16                                   13.7                      7.4
# 17                                   14.4                      8.0
# 18                                   18.3                      9.7
# 19                                   16.6                      9.1
# 20                                   14.1                      7.7
# 21                                   17.7                      9.8
# 22                                   16.8                      9.1
# 23                                   14.4                      8.1
# 24                                   16.7                      8.8
# 25                                   13.6                      7.6
# 26                                   13.9                      7.9
# 27                                   17.8                      9.5
# 28                                   13.5                      7.6
# 29                                   17.0                      9.1
# 30                                   15.7                      8.5
# 31                                   16.8                      9.3
# 32                                   17.0                      9.1
#
# [33 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['borough_name', 'borough_code', 'borough_area_hectare',
#        'green_area_hectare', 'blue _area_hectare', 'green+blue_area_hectare',
#        'percent_green', 'percent_blue', 'percent_green+blue', 'population',
#        'death_persons', 'death_males', 'death_females',
#        'standard_mortality_ratio_persons', 'standard_mortality_ratio_males',
#        'standard_mortality_ratio_females', 'life_expectancy_birth_males',
#        'life_expectancy_birth_females', 'life_expectancy_65_males',
#        'life_expectancy_65_females', 'DSR_annual_age15+_persons',
#        'DSR_annual_age15+_males', 'DSR_annual_age15+_females',
#        'number_annual_age15+_persons', 'number_annual_age15+_males',
#        'number_annual_age15+_females', 'meanpercent_homes_with_good_access',
#        'meanpercent_home_with_deficiency_access',
#        'any_neurotic_disorder_per1000', 'all_phobias_per1000',
#        'depressive_episode_per1000', 'generalised_anxiety_disorder_per1000',
#        'mixed_anxiety_depression', 'obsessive_compulsive_disorder_per1000',
#        'panic_ disorder_per1000'],
#       dtype='object')

# %%
pop = ['population']
df.sample(5, random_state=42)[pop]
# Out:
#    population
# 31    307,000
# 15    237,200
# 26    187,000
# 17    254,000
# 8     338,400

# %%
for p in pop:
    print(f"Converting {p}")
    df[p] = df[p].str.replace('$','', regex=False).str.replace(',','', regex=False).astype('float')
# Out:
# Converting population

# %%
df.sample(5, random_state=42)[pop]
# Out:
#     population
# 31    307000.0
# 15    237200.0
# 26    187000.0
# 17    254000.0
# 8     338400.0

# %%
death = ['death_persons']
df.sample(5, random_state=42)[death]
# Out:
#    death_persons
# 31         1,442
# 15         2,193
# 26         1,110
# 17         1,372
# 8          1,889

# %%
for d in death:
    print(f"Converting {d}")
    df[d] = df[d].str.replace('$','', regex=False).str.replace(',','', regex=False).astype('float')
# Out:
# Converting death_persons

# %%
df.sample(5, random_state=42)[death]
# Out:
#     death_persons
# 31         1442.0
# 15         2193.0
# 26         1110.0
# 17         1372.0
# 8          1889.0

# %%
df['death_persons'].max()
# Out:
# 2631.0

# %% [markdown]
# ### Green area distribution

# %%
df.percent_green.plot.kde(xlim=(0,100));

# %%
df.percent_green.plot.hist(bins=100);

# %%
df.percent_green.plot.box(figsize=(4, 8)); # boxplot

# %% [markdown]
# ### Exploratory data analysis

# %% [markdown]
# **Green space and life expectancy**

# %%
fig, axs = plt.subplots(1, 2, sharey=True)
df.plot(kind='scatter', x='life_expectancy_birth_males', y='percent_green', ax=axs[0], figsize=(16, 8))
df.plot(kind='scatter', x='life_expectancy_birth_females', y='percent_green', ax=axs[1])
# Out:
# <Axes: xlabel='life_expectancy_birth_females', ylabel='percent_green'>

# %% [markdown]
# **Green space and deaths**

# %%
fig, axs = plt.subplots(1, 3, sharey=True)
df.plot(kind='scatter', x='death_persons', y='percent_green', ax=axs[0], figsize=(48, 16))
df.plot(kind='scatter', x='death_males', y='percent_green', ax=axs[1])
df.plot(kind='scatter', x='death_females', y='percent_green', ax=axs[2])
# Out:
# <Axes: xlabel='death_females', ylabel='percent_green'>
